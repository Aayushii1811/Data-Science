# %%
class Employee:
    def _init_(self):
        self.empid = None
        self.name = None
        self.basic_salary = None
        self.experience_years = None
        self.hra = None
        self.da = None
        self.pf = None
        self.bonus = None
        self.net_salary = None

    
    def get_empid(self):
        return self.empid

    def set_empid(self, empid):
        self.empid = empid

    def get_name(self):
        return self.name

    def set_name(self, name):
        self.name = name

    def get_basic_salary(self):
        return self.basic_salary

    def set_basic_salary(self, basic_salary):
        self.basic_salary = basic_salary

    def get_experience_years(self):
        return self.experience_years

    def set_experience_years(self, experience_years):
        self.experience_years = experience_years
    
    def calculate_hra(self):
        self.hra = 0.35 * self.basic_salary

    def calculate_da(self):
        self.da = 0.58 * self.basic_salary

    def calculate_pf(self):
        self.pf = 0.095 * self.basic_salary

    def calculate_bonus(self):
        if self.experience_years >= 30:
            self.bonus = 0.59 * self.basic_salary
        elif self.experience_years >= 23:
            self.bonus = 0.51 * self.basic_salary
        elif self.experience_years >= 15:
            self.bonus = 0.45 * self.basic_salary
        elif self.experience_years >= 7:
            self.bonus = 0.33 * self.basic_salary
        else:
            self.bonus = 0.16 * self.basic_salary

    def calculate_net_salary(self):
        self.net_salary = (
            self.basic_salary + self.hra + self.da + self.pf + self.bonus
        )



def main():
    employee = Employee()

    
    employee.set_empid(input("Enter employee ID: "))
    employee.set_name(input("Enter employee name: "))
    employee.set_basic_salary(float(input("Enter basic salary: ")))
    employee.set_experience_years(int(input("Enter years of experience: ")))

    
    employee.calculate_hra()
    employee.calculate_da()
    employee.calculate_pf()
    employee.calculate_bonus()
    employee.calculate_net_salary()

    
    print("\nEmployee Details:")
    print("Employee ID:", employee.get_empid())
    print("Employee Name:", employee.get_name())
    print("Basic Salary:", employee.get_basic_salary())
    print("Experience (in years):", employee.get_experience_years())

    print("\nCalculated Components:")
    print("HRA:", employee.hra)
    print("DA:", employee.da)
    print("PF:", employee.pf)
    print("Bonus:", employee.bonus)

    print("\nNet Salary:", employee.net_salary)


if __name__ == "__main__":
   main()
# Out:
# Enter employee ID: 22000213
# Enter employee name: Aayushi Desai
# Enter basic salary: 200000
# Enter years of experience: 5
#
# Employee Details:
# Employee ID: 22000213
# Employee Name: Aayushi Desai
# Basic Salary: 200000.0
# Experience (in years): 5
#
# Calculated Components:
# HRA: 70000.0
# DA: 115999.99999999999
# PF: 19000.0
# Bonus: 32000.0
#
# Net Salary: 437000.0

# %%
class NumberProcessor:
    def _init_(self):
        self.number_list = []
        self.new_list = []

    def input_numbers(self, n):
        print("Enter {n} numbers:")
        for _ in range(n):
            number = float(input())
            self.number_list.append(number)

    def calculate_and_create_new_list(self):
        length = len(self.number_list)
        for i in range(length // 2):
            sum_result = self.number_list[i] + self.number_list[length - 1 - i]
            self.new_list.append(sum_result)

    def remove_duplicates_and_display(self):
        unique_set = set(self.new_list)
        unique_tuple = tuple(unique_set)
        print("Resulting Tuple after removing duplicates:", unique_tuple)



num_processor = NumberProcessor()
num_processor.input_numbers(8)
num_processor.calculate_and_create_new_list()
num_processor.remove_duplicates_and_display()
# Out:
# Enter {n} numbers:
# 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6608\140828553.py in <module>
#      24
#      25 num_processor = NumberProcessor()
# ---> 26 num_processor.input_numbers(8)
#      27 num_processor.calculate_and_create_new_list()
#      28 num_processor.remove_duplicates_and_display()
#
# ~\AppData\Local\Temp\ipykernel_6608\140828553.py in input_numbers(self, n)
#       8         for _ in range(n):
#       9             number = float(input())
# ---> 10             self.number_list.append(number)
#      11
#      12     def calculate_and_create_new_list(self):
#
# AttributeError: 'NumberProcessor' object has no attribute 'number_list'

# %%
class NumberProcessor:
    def _init_(self):
        self.number_list = []
        self.new_list = []

    def input_numbers(self, n):
        print("Enter {n} numbers:")
        for _ in range(n):
            number = float(input())
            self.number_list.append(number)

    def calculate_and_create_new_list(self):
        length = len(self.number_list)
        for i in range(length // 2):
            sum_result = self.number_list[i] + self.number_list[length - 1 - i]
            self.new_list.append(sum_result)

    def remove_duplicates_and_display(self):
        unique_set = set(self.new_list)
        unique_tuple = tuple(unique_set)
        print("Resulting Tuple after removing duplicates:", unique_tuple)



num_processor = NumberProcessor()
num_processor.input_numbers(8)
num_processor.calculate_and_create_new_list()
num_processor.remove_duplicates_and_display()
# Out:
# Enter {n} numbers:
# 8
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6608\140828553.py in <module>
#      24
#      25 num_processor = NumberProcessor()
# ---> 26 num_processor.input_numbers(8)
#      27 num_processor.calculate_and_create_new_list()
#      28 num_processor.remove_duplicates_and_display()
#
# ~\AppData\Local\Temp\ipykernel_6608\140828553.py in input_numbers(self, n)
#       8         for _ in range(n):
#       9             number = float(input())
# ---> 10             self.number_list.append(number)
#      11
#      12     def calculate_and_create_new_list(self):
#
# AttributeError: 'NumberProcessor' object has no attribute 'number_list'

# %%
class addition:
    def __init__(self):
        self.num1 = None
        self.num2 = None
        self.num3 = None
        
    def get_num1(self):
        return self.num1
    def set_num1(self,num1):
        self.num1 = num1
    def get_num2(self):
        return self.num2
    def set_num2(self,num2):
        self.num2 = num2
    def get_num3(self):
        return self.num3
    def set_num3(self):
        self.num3 = self.num1+self.num2
    def get_num4(self):
        return self.num4
    def set_num4(self):
        self.num4 = self.num1**self.num2
    def get_num5(self):
        return self.num5
    def set_num5(self):
        self.num5 = int(str(self.num1)+str(self.num2))
    def get_num6(self):
        return self.num6
    def set_num6(self):
        self.num6 = max(self.num1,self.num2)
    def get_num7(self):
         return self.num7
    def set_num7(self):
         self.num7 = min(self.num1,self.num2)
    
    
        
def main():
        number = addition()
    
        number.set_num1(int(input("Enter the number=")))
        number.set_num2(int(input("Enter the number=")))
           
        number.set_num3() 
        number.set_num4() 
        number.set_num5() 
        number.set_num6() 
        number.set_num7() 
       
        
       
       
        print("Number is",number.get_num1())
        print("Number is",number.get_num2())
        print("Addition is",number.get_num3())
        print("Power is",number.get_num4())
        print("Concatenation is",number.get_num5())
        print("Max number is",number.get_num6())
        print("Min number is",number.get_num7())
        
        
if __name__ == "__main__":
           main()
# Out:
# Enter the number=11
# Enter the number=18
# Number is 11
# Number is 18
# Addition is 29
# Power is 5559917313492231481
# Concatenation is 1118
# Max number is 18
# Min number is 11
